# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import datetime

# Define the start and end dates
start = datetime.datetime(2015, 1, 1)
end = datetime.datetime(2025, 1, 1)

# Fetch Tesla stock data using yfinance
tesla = yf.download('TSLA', start=start, end=end)

tesla.head()
# Out:
# /var/folders/8q/_sl8n9_s02xfv0sdvpz0dr8m0000gn/T/ipykernel_64516/1123812471.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla = yf.download('TSLA', start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           TSLA       TSLA       TSLA       TSLA      TSLA
# Date
# 2015-01-02  14.620667  14.883333  14.217333  14.858000  71466000
# 2015-01-05  14.006000  14.433333  13.810667  14.303333  80527500
# 2015-01-06  14.085333  14.280000  13.614000  14.004000  93928500
# 2015-01-07  14.063333  14.318667  13.985333  14.223333  44526000
# 2015-01-08  14.041333  14.253333  14.000667  14.187333  51637500

# %%
Apple = yf.download('AAPL', start=start, end=end)
Apple.head()
# Out:
# /var/folders/8q/_sl8n9_s02xfv0sdvpz0dr8m0000gn/T/ipykernel_64516/2361598532.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Apple = yf.download('AAPL', start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-01-02  24.288580  24.757334  23.848706  24.746226  212818400
# 2015-01-05  23.604332  24.137513  23.417720  24.057535  257142000
# 2015-01-06  23.606556  23.866481  23.244437  23.668760  263188400
# 2015-01-07  23.937571  24.037541  23.704304  23.815383  160423600
# 2015-01-08  24.857309  24.915071  24.148623  24.266369  237458000

# %%
nvidia = yf.download('NVDA', start=start, end=end)
nvidia.head()
# Out:
# /var/folders/8q/_sl8n9_s02xfv0sdvpz0dr8m0000gn/T/ipykernel_64516/1769109506.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nvidia = yf.download('NVDA', start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          NVDA      NVDA      NVDA      NVDA       NVDA
# Date
# 2015-01-02  0.483066  0.486665  0.475386  0.483066  113680000
# 2015-01-05  0.474906  0.484505  0.472747  0.483066  197952000
# 2015-01-06  0.460508  0.476106  0.460028  0.475626  197764000
# 2015-01-07  0.459308  0.467947  0.457868  0.463868  321808000
# 2015-01-08  0.476586  0.479466  0.464348  0.464588  283780000

# %%
tesla['Open'].plot(label='Tesla', figsize=(16, 8), title='Open Price')
Apple['Open'].plot(label='Apple')
nvidia['Open'].plot(label='Nvidia')
plt.legend();

# %%
# Use the 'Close' column instead of 'Adj Close' if 'Adj Close' is not available
tesla['Close'].plot(label='Tesla', figsize=(16, 8), title='Close Price')
Apple['Close'].plot(label='Apple')
nvidia['Close'].plot(label='Nvidia')
plt.legend();
